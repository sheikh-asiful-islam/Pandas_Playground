# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-asiful-islam/Pandas_Playground/blob/main/Pandas_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# rename pandas as pd
import pandas as pd

# %%
# 2 main data types (1.Series and 2.DataFrame)
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1 -dimentional

# %%
colours = pd.Series(["red", "Blue", "White"])
colours
# Out:
# 0      red
# 1     Blue
# 2    White
# dtype: object
